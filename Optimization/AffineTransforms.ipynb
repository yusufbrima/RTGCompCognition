# %%
from celluloid import Camera # getting the camera
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull, convex_hull_plot_2d
from IPython.display import HTML # to show the animation in Jupyter
import IPython.display as ipd
import warnings
warnings.simplefilter(action='ignore')
# %matplotlib inline

# %%
img = plt.imread("pic.jpg")
# ipd.Image("pic.jpg")

# %%
image = Image.open("pic.jpg")

# %%
imx = image.thumbnail((128,128))

# %%
# image.save(imx,'JPEG')

# %%
image.resize((128,128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F9C6D25C2B0>

# %%
image.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=128x83 at 0x7F9C693A74C0>

# %%
from PIL import ImageFilter
image.filter(ImageFilter.DETAIL)
# Out:
# <PIL.Image.Image image mode=RGB size=128x83 at 0x7F9C68895D00>

# %%
image.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=128x83 at 0x7F9C6AC0AD60>

# %%
# from pathlib import Path
# import glob

# paths = Path(".").glob("*.png")

# %%
from PIL import ImageEnhance

enh = ImageEnhance.Contrast(image)
enh.enhance(1.7).show("30% more contrast")

# %%
img
