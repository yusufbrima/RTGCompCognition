# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import os
from plotnine import *
from plotnine.data import mtcars

# %%
(ggplot(mtcars, aes(x="wt",y="mpg"))+ geom_point())
# Out:
# <ggplot: (8749308739837)>

# %%
(ggplot(mtcars, aes(x="wt",y="mpg"))+ geom_point() + stat_smooth(method="lm") + facet_wrap("gear"))
# Out:
# <ggplot: (8749308504447)>
